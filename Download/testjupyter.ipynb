# %%
# 그래프를 노트북 안에 그리기 위해 설정
# %matplotlib inline

# 필요한 패키지와 라이브러리를 가져옴
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 그래프에서 마이너스 폰트 깨지는 문제에 대한 대처
mpl.rcParams['axes.unicode_minus'] = False

# %%
import numpy as np

data = np.random.randint(-100, 100, 50).cumsum()
data
# Out:
# array([ -86, -107, -118,  -67,  -74,  -34,  -27,    1,   65,  160,  170,
#         249,  256,  216,  242,  311,  341,  284,  246,  263,  206,  182,
#          93,   -5,  -65,   -7,   80,   89,  124,  198,  155,  207,  136,
#          87,  166,  240,  191,  229,  258,  205,  232,  171,  123,  105,
#         193,  201,  203,  259,  190,  191], dtype=int32)

# %%
plt.plot(range(50), data, 'r')
mpl.rcParams['axes.unicode_minus'] = False
plt.title('시간별 가격 추이')
plt.ylabel('주식 가격')
plt.xlabel('시간(분)')
# Out:
# Text(0.5, 0, '시간(분)')

# %%
print ('버전: ', mpl.__version__)
print ('설치 위치: ', mpl.__file__)
print ('설정 위치: ', mpl.get_configdir())
print ('캐시 위치: ', mpl.get_cachedir())
# Out:
# 버전:  3.1.3
# 설치 위치:  C:\Users\MCF\anaconda3\lib\site-packages\matplotlib\__init__.py
# 설정 위치:  C:\Users\MCF\.matplotlib
# 캐시 위치:  C:\Users\MCF\.matplotlib

# %%
print ('설정파일 위치: ', mpl.matplotlib_fname())
# Out:
# 설정파일 위치:  C:\Users\MCF\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
[(f.name, f.fname) for f in fm.fontManager.ttflist if 'Nanum' in f.name]
# Out:
# [('Nanum Brush Script', 'C:\\Windows\\Fonts\\NanumBrush.ttf'),
#  ('NanumGothic', 'C:\\WINDOWS\\Fonts\\NanumGothicBold.ttf'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\NanumGothicExtraBold.ttf'),
#  ('NanumMyeongjo', 'C:\\WINDOWS\\Fonts\\NanumMyeongjoBold.ttf'),
#  ('Nanum Pen Script', 'C:\\Windows\\Fonts\\NanumPen.ttf'),
#  ('NanumGothic', 'C:\\Windows\\Fonts\\NanumGothic.ttf'),
#  ('NanumMyeongjo', 'C:\\Windows\\Fonts\\NanumMyeongjoExtraBold.ttf'),
#  ('NanumMyeongjo', 'C:\\WINDOWS\\Fonts\\NanumMyeongjo.ttf')]
